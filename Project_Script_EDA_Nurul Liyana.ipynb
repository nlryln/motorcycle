# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('df_merge.csv')   #mc1 merge with sd1 motor specs, sd5 prices, sd6 prices
sd2 = pd.read_csv('sd2.csv')   
sd3 = pd.read_csv('sd3.csv')   
sd4 = pd.read_csv('sd4.csv')

# %% [markdown]
# # SD2

# %% [markdown]
# From sd2, look at the yearly registration of motorbikes by Brand for the client to see the top 5 bikes that is registered to be sell yearly.Get top 5 in each year and see if there’s much different if no then get the top 5 if yes, get the bike that is rising to be part of the top 5 to sell

# %%
sd2.head()
# Out:
#    Unnamed: 0  year   Brand  no. of motorcycles
# 0           0  2005  yamaha                3063
# 1           1  2005   honda                5405
# 2           2  2005     sym                 589
# 3           3  2005     bmw                  34
# 4           4  2005     ktm                  28

# %%
sd2.drop(columns=['Unnamed: 0'],inplace=True)

# %%
sd2.year.unique()
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017])

# %% [markdown]
# ## SD2 5 years

# %%
sd2_5years = sd2.loc[(sd2['year'].isin([2013,2014,2015,2016,2017]))]

# %%
sd2_5years.head(10)
# Out:
#      year     Brand  no. of motorcycles
# 488  2013    yamaha                5334
# 489  2013     honda                2046
# 490  2013       sym                 881
# 491  2013       bmw                 360
# 492  2013       ktm                 310
# 493  2013   piaggio                 542
# 494  2013    suzuki                 163
# 495  2013  kawasaki                 271
# 496  2013     kymco                 190
# 497  2013    ducati                 159

# %%
sd2_5years.sort_values('no. of motorcycles', ascending=False, inplace=True)
# Out:
# /var/folders/bq/1n8bgy_57l74n18m4pnvpyj00000gn/T/ipykernel_2528/2299377148.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd2_5years.sort_values('no. of motorcycles', ascending=False, inplace=True)

# %%
sd2_5years.groupby(['year','Brand'],sort=False)[['no. of motorcycles']].max().head(40)
# Out:
#                no. of motorcycles
# year Brand
# 2013 yamaha                  5334
# 2017 yamaha                  3764
#      honda                   3125
# 2016 yamaha                  3037
# 2014 yamaha                  2764
# 2015 yamaha                  2353
# 2016 honda                   2324
# 2013 honda                   2046
# 2015 honda                   1960
# 2014 honda                   1932
# 2013 sym                      881
#      piaggio                  542
# 2014 sym                      472
#      bmw                      466
# 2016 suzuki                   443
# 2015 suzuki                   440
# 2013 bajaj                    422
# 2014 ktm                      405
# 2016 bmw                      392
# 2017 suzuki                   387
# 2015 bmw                      385
#      ktm                      381
# 2014 piaggio                  368
# 2013 bmw                      360
# 2015 piaggio                  336
# 2016 ktm                      329
# ...

# %%
sd2_5years.groupby(['year','Brand'],sort=False)[['no. of motorcycles']].max().head(37).unstack().plot.bar(figsize=(8,5),edgecolor='midnightblue')
# Out:
# <AxesSubplot: xlabel='year'>

# %%
sd2_2017 = sd2.loc[(sd2['year']==2017)]
sd2_2016 = sd2.loc[(sd2['year']==2016)]
sd2_2015 = sd2.loc[(sd2['year']==2015)]
sd2_2014 = sd2.loc[(sd2['year']==2014)]
sd2_2013 = sd2.loc[(sd2['year']==2013)]

# %% [markdown]
# ### SD2 2013

# %%
sd2_2013.head(5)
# Out:
#      year   Brand  no. of motorcycles
# 488  2013  yamaha                5334
# 489  2013   honda                2046
# 490  2013     sym                 881
# 491  2013     bmw                 360
# 492  2013     ktm                 310

# %%
sd2_2013.sort_values('no. of motorcycles', ascending=False, inplace=True)
sd2_2013.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5)
# Out:
# /var/folders/bq/1n8bgy_57l74n18m4pnvpyj00000gn/T/ipykernel_2528/3287469002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd2_2013.sort_values('no. of motorcycles', ascending=False, inplace=True)
#          no. of motorcycles
# Brand
# yamaha                 5334
# honda                  2046
# sym                     881
# piaggio                 542
# bajaj                   422

# %%
sd2_2013.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5).unstack().plot.barh(figsize=(4,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='None,Brand'>

# %% [markdown]
# ### SD2 2014

# %%
sd2_2014.head(5)
# Out:
#      year   Brand  no. of motorcycles
# 549  2014  yamaha                2764
# 550  2014   honda                1932
# 551  2014     sym                 472
# 552  2014     bmw                 466
# 553  2014     ktm                 405

# %%
sd2_2014.sort_values('no. of motorcycles', ascending=False, inplace=True)
sd2_2014.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5)
# Out:
# /var/folders/bq/1n8bgy_57l74n18m4pnvpyj00000gn/T/ipykernel_2528/1199943437.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd2_2014.sort_values('no. of motorcycles', ascending=False, inplace=True)
#         no. of motorcycles
# Brand
# yamaha                2764
# honda                 1932
# sym                    472
# bmw                    466
# ktm                    405

# %%
sd2_2014.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5).unstack().plot.barh(figsize=(4,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='None,Brand'>

# %% [markdown]
# ### SD2 2015

# %%
sd2_2015.head(5)
# Out:
#      year    Brand  no. of motorcycles
# 610  2015   a-bike                   6
# 611  2015    adiva                 173
# 612  2015  aprilia                  87
# 613  2015      bmw                 385
# 614  2015    bajaj                  60

# %%
sd2_2015.sort_values('no. of motorcycles', ascending=False, inplace=True)
sd2_2015.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5)
# Out:
# /var/folders/bq/1n8bgy_57l74n18m4pnvpyj00000gn/T/ipykernel_2528/526123764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd2_2015.sort_values('no. of motorcycles', ascending=False, inplace=True)
#         no. of motorcycles
# Brand
# yamaha                2353
# honda                 1960
# suzuki                 440
# bmw                    385
# ktm                    381

# %%
sd2_2015.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5).unstack().plot.barh(figsize=(4,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='None,Brand'>

# %% [markdown]
# ### SD2 2016

# %%
sd2_2016.head(5)
# Out:
#      year    Brand  no. of motorcycles
# 662  2016   a-bike                   0
# 663  2016    adiva                 182
# 664  2016  aprilia                  71
# 665  2016      bmw                 392
# 666  2016    bajaj                 140

# %%
sd2_2016.sort_values('no. of motorcycles', ascending=False, inplace=True)
sd2_2016.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5)
# Out:
# /var/folders/bq/1n8bgy_57l74n18m4pnvpyj00000gn/T/ipykernel_2528/3139415024.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd2_2016.sort_values('no. of motorcycles', ascending=False, inplace=True)
#         no. of motorcycles
# Brand
# yamaha                3037
# honda                 2324
# suzuki                 443
# bmw                    392
# ktm                    329

# %%
sd2_2016.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5).unstack().plot.barh(figsize=(4,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='None,Brand'>

# %% [markdown]
# ### SD2 2017

# %%
sd2_2017.head(5)
# Out:
#      year    Brand  no. of motorcycles
# 714  2017   a-bike                   0
# 715  2017    adiva                 194
# 716  2017  aprilia                  51
# 717  2017      bmw                 236
# 718  2017    bajaj                 114

# %%
sd2_2017.sort_values('no. of motorcycles', ascending=False, inplace=True)
sd2_2017.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5)
# Out:
# /var/folders/bq/1n8bgy_57l74n18m4pnvpyj00000gn/T/ipykernel_2528/4030641282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd2_2017.sort_values('no. of motorcycles', ascending=False, inplace=True)
#          no. of motorcycles
# Brand
# yamaha                 3764
# honda                  3125
# suzuki                  387
# piaggio                 322
# ktm                     312

# %%
sd2_2017.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5).unstack().plot.barh(figsize=(4,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='None,Brand'>

# %% [markdown]
# Conclusion: Motorcycle shop sellers brings in these top 5 brands each year, although the numbers is decreasing by year but these are the top 5.
# 1. Yamaha, numbers is decreasing by year but is still the top brand that is brought in
# 2. Honda, is the second top and is increasing by year
# 3. Suzuki, was at the 12th position but manage to bring in more and be the top 3 in 2017
# 4. KTM, same goes here, only bring in more in 2015 onwards
# 5. Piaggo, has been consistently in the charts for the past 5 years
# 6. SYM, although it died down in 2016, but they brought back in SYM, probably in demand

# %% [markdown]
# # SD3

# %% [markdown]
# From sd3 , look at the top 5 bikes that is used in Singapore, and does it match with the top 5 yearly registration, if yes, proceed to choose the same top 5 bikes, if no, look at the bikes that is not part of the yearly registration so that you can put in the top 5 list to sell

# %%
sd3.head()
# Out:
#    Unnamed: 0  year    Brand  no. of motorcycles
# 0           0  2005    adiva                   0
# 1           1  2005  aprilia                1075
# 2           2  2005      bmw                 610
# 3           3  2005      bsa                  12
# 4           4  2005    bajaj                 198

# %%
sd3.drop(columns=['Unnamed: 0'],inplace=True)

# %%
sd3.year.unique()
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017])

# %% [markdown]
# ## SD3 5 years

# %%
sd3_5years = sd3.loc[(sd3['year'].isin([2013,2014,2015,2016,2017]))]

# %%
sd3_5years.head(10)
# Out:
#      year    Brand  no. of motorcycles
# 488  2013    adiva                  97
# 489  2013  aprilia                1436
# 490  2013      bmw                1502
# 491  2013      bsa                  21
# 492  2013    bajaj                2688
# 493  2013  benelli                  26
# 494  2013   bimota                   7
# 495  2013   cagiva                  65
# 496  2013   can-am                  37
# 497  2013  chunlan                   0

# %%
sd3_5years.sort_values('no. of motorcycles', ascending=False, inplace=True)
# Out:
# /var/folders/bq/1n8bgy_57l74n18m4pnvpyj00000gn/T/ipykernel_2528/994789820.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd3_5years.sort_values('no. of motorcycles', ascending=False, inplace=True)

# %%
sd3_5years.groupby(['year','Brand'],sort=False)[['no. of motorcycles']].max().head(25)
# Out:
#               no. of motorcycles
# year Brand
# 2013 honda                 55797
# 2014 honda                 54633
# 2015 honda                 53256
# 2016 honda                 52246
# 2017 honda                 50118
#      yamaha                48664
# 2014 yamaha                47651
# 2016 yamaha                47503
# 2013 yamaha                47390
# 2015 yamaha                47389
# 2013 piaggio                8298
# 2014 piaggio                8126
# 2015 piaggio                7825
# 2016 piaggio                7391
# 2017 piaggio                6962
# 2013 suzuki                 6771
# 2014 suzuki                 6442
# 2015 suzuki                 6387
# 2016 suzuki                 6277
# 2017 suzuki                 6076
#      sym                    4598
# 2015 sym                    4480
# 2014 sym                    4479
# 2016 sym                    4471
# 2013 sym                    4142

# %%
sd3_5years.groupby(['year','Brand'],sort=False)[['no. of motorcycles']].max().head(25).unstack().plot.bar(figsize=(8, 5),edgecolor='midnightblue')
#plot.legend(loc=2, prop={'size': 6})
# Out:
# <AxesSubplot: xlabel='year'>

# %%
sd3_2017 = sd3.loc[(sd3['year']==2017)]
sd3_2016 = sd3.loc[(sd3['year']==2016)]
sd3_2015 = sd3.loc[(sd3['year']==2015)]
sd3_2014 = sd3.loc[(sd3['year']==2014)]
sd3_2013 = sd3.loc[(sd3['year']==2013)]

# %% [markdown]
# ### SD3 2013

# %%
sd3_2013.head(5)
# Out:
#      year    Brand  no. of motorcycles
# 488  2013    adiva                  97
# 489  2013  aprilia                1436
# 490  2013      bmw                1502
# 491  2013      bsa                  21
# 492  2013    bajaj                2688

# %%
sd3_2013.sort_values('no. of motorcycles', ascending=False, inplace=True)
sd3_2013.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5)
# Out:
# /var/folders/bq/1n8bgy_57l74n18m4pnvpyj00000gn/T/ipykernel_2528/2797660549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd3_2013.sort_values('no. of motorcycles', ascending=False, inplace=True)
#          no. of motorcycles
# Brand
# honda                 55797
# yamaha                47390
# piaggio                8298
# suzuki                 6771
# sym                    4142

# %%
sd3_2013.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5).unstack().plot.barh(figsize=(4,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='None,Brand'>

# %% [markdown]
# ### SD3 2014

# %%
sd3_2014.head(5)
# Out:
#      year    Brand  no. of motorcycles
# 549  2014    adiva                 221
# 550  2014  aprilia                1451
# 551  2014      bmw                1950
# 552  2014      bsa                  22
# 553  2014    bajaj                2745

# %%
sd3_2014.sort_values('no. of motorcycles', ascending=False, inplace=True)
sd3_2014.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5)
# Out:
# /var/folders/bq/1n8bgy_57l74n18m4pnvpyj00000gn/T/ipykernel_2528/1909262616.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd3_2014.sort_values('no. of motorcycles', ascending=False, inplace=True)
#          no. of motorcycles
# Brand
# honda                 54633
# yamaha                47651
# piaggio                8126
# suzuki                 6442
# sym                    4479

# %%
sd3_2014.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5).unstack().plot.barh(figsize=(4,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='None,Brand'>

# %% [markdown]
# ### SD3 2015

# %%
sd3_2015.head(5)
# Out:
#      year    Brand  no. of motorcycles
# 610  2015   a-bike                   6
# 611  2015    adiva                 393
# 612  2015  aprilia                1414
# 613  2015      bmw                2319
# 614  2015      bsa                  21

# %%
sd3_2015.sort_values('no. of motorcycles', ascending=False, inplace=True)
sd3_2015.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5)
# Out:
# /var/folders/bq/1n8bgy_57l74n18m4pnvpyj00000gn/T/ipykernel_2528/890233654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd3_2015.sort_values('no. of motorcycles', ascending=False, inplace=True)
#          no. of motorcycles
# Brand
# honda                 53256
# yamaha                47389
# piaggio                7825
# suzuki                 6387
# sym                    4480

# %%
sd3_2015.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5).unstack().plot.barh(figsize=(4,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='None,Brand'>

# %% [markdown]
# ### SD3 2016

# %%
sd3_2016.head(5)
# Out:
#      year    Brand  no. of motorcycles
# 674  2016   a-bike                   6
# 675  2016    adiva                 569
# 676  2016  aprilia                1379
# 677  2016      bmw                2690
# 678  2016      bsa                   0

# %%
sd3_2016.sort_values('no. of motorcycles', ascending=False, inplace=True)
sd3_2016.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5)
# Out:
# /var/folders/bq/1n8bgy_57l74n18m4pnvpyj00000gn/T/ipykernel_2528/2130327536.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd3_2016.sort_values('no. of motorcycles', ascending=False, inplace=True)
#          no. of motorcycles
# Brand
# honda                 52246
# yamaha                47503
# piaggio                7391
# suzuki                 6277
# sym                    4471

# %%
sd3_2016.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5).unstack().plot.barh(figsize=(4,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='None,Brand'>

# %% [markdown]
# ### SD3 2017

# %%
sd3_2017.head(5)
# Out:
#      year    Brand  no. of motorcycles
# 737  2017   a-bike                   5
# 738  2017    adiva                 758
# 739  2017  aprilia                1342
# 740  2017      bmw                2890
# 741  2017      bsa                  21

# %%
sd3_2017.sort_values('no. of motorcycles', ascending=False, inplace=True)
sd3_2017.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5)
# Out:
# /var/folders/bq/1n8bgy_57l74n18m4pnvpyj00000gn/T/ipykernel_2528/920207943.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd3_2017.sort_values('no. of motorcycles', ascending=False, inplace=True)
#          no. of motorcycles
# Brand
# honda                 50118
# yamaha                48664
# piaggio                6962
# suzuki                 6076
# sym                    4598

# %%
sd3_2017.groupby(['Brand'],sort=False)[['no. of motorcycles']].max().head(5).unstack().plot.barh(figsize=(4,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='None,Brand'>

# %% [markdown]
# Conclusion: The population choses to use these brands, there could be 5 possible reasons.
# 1. Popularity, where most riders are buying the similar bikes.
#
# 2. Daily use, nowadays, riders tend to go for auto bikes and since singapore doesnt allow to go at a speed of over 90km/h, most riders choose to buy a smaller cc bike.
#
# 3. Outlook, personally for me as a rider, i would like to buy a good looking bike, such as dragosta(PLS SHOW PHOTO) or Husqvarna(SHOW ALSO). However these bikes are usually pricier than regular bikes.
#
# 4. Collection, there are riders, who buy bikes for hobby or collection, such as vintage bikes(SHOW PHOTOS AGAIN) or rare bikes(SHOW ALSO).
#
# 5, Services, lastly this kind of bikes where delivery riders use to deilver food/documents, not so much of presentation, more to technicality.
#
# So this is the top 5 brands, that is used in singapore and as you can see its been the strong 5 brands.
#
# 1. Honda
# 2. Yamaha
# 3. Piaggio
# 4. Suzuki
# 5. SYM

# %% [markdown]
# # SD4

# %% [markdown]
# From sd4, also looking at the top 5 bikes yearly but in CC rate which means I get to see the different classes of bikes, from class 2b to 2a to 2. Can see if the top 5 of each classes is the same or different class prefers to use different brands

# %%
sd4.head()
# Out:
#    Unnamed: 0  year        cc_rating  no. of motorcycles
# 0           0  2005  100cc and below                3049
# 1           1  2005        101-200cc              104528
# 2           2  2005        201-300cc                3268
# 3           3  2005        301-400cc               18375
# 4           4  2005        401-500cc                 209

# %%
sd4.drop(columns=['Unnamed: 0'],inplace=True)

# %%
sd4.year.unique()
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017])

# %% [markdown]
# ## SD4 5 years

# %%
sd4_5years = sd4.loc[(sd4['year'].isin([2013,2014,2015,2016,2017]))]

# %%
sd4_5years.head(10)
# Out:
#     year         cc_rating  no. of motorcycles
# 56  2013   100cc and below                 745
# 57  2013         101-200cc              105735
# 58  2013         201-300cc                2973
# 59  2013         301-400cc               17993
# 60  2013         401-500cc                 440
# 61  2013        501-1000cc               10246
# 62  2013  1001cc and above                6175
# 63  2014   100cc and below                 684
# 64  2014         101-200cc              103249
# 65  2014         201-300cc                3054

# %%
sd4.cc_rating.unique()
# Out:
# array(['100cc and below', '101-200cc', '201-300cc', '301-400cc',
#        '401-500cc', '501-1000cc', '1001cc and above'], dtype=object)

# %%
sd4_5years.sort_values('no. of motorcycles', ascending=False, inplace=True)
# Out:
# /var/folders/bq/1n8bgy_57l74n18m4pnvpyj00000gn/T/ipykernel_2528/2029032907.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd4_5years.sort_values('no. of motorcycles', ascending=False, inplace=True)

# %%
sd4_5years.groupby(['year','cc_rating'],sort=False)[['no. of motorcycles']].max()
# Out:
#                        no. of motorcycles
# year cc_rating
# 2013 101-200cc                     105735
# 2014 101-200cc                     103249
# 2015 101-200cc                      99765
# 2016 101-200cc                      97306
# 2017 101-200cc                      94609
#      301-400cc                      19937
# 2016 301-400cc                      19817
# 2015 301-400cc                      19513
# 2014 301-400cc                      18773
# 2013 301-400cc                      17993
# 2017 501-1000cc                     13585
# 2016 501-1000cc                     12864
# 2015 501-1000cc                     12061
# 2014 501-1000cc                     11103
# 2013 501-1000cc                     10246
# 2017 1001cc and above                8881
# 2016 1001cc and above                8414
# 2015 1001cc and above                7807
# 2014 1001cc and above                7104
# 2013 1001cc and above                6175
# 2017 201-300cc                       3330
# ...

# %%
sd4_all = sd4_5years.groupby(['year','cc_rating'],sort=False)[['no. of motorcycles']].max().unstack()
sd4_all.sort_values(by=['year']).plot.bar(figsize=(8, 5),edgecolor='midnightblue')
#plot.legend(loc=2, prop={'size': 6})
# Out:
# <AxesSubplot: xlabel='year'>

# %% [markdown]
# Conclusion: Like being said earlier, Singapore speed limit is 90 km/h max, so you can rarely see that bikes that has a cc below 100(the brown one which cant be seen at all, and also cc from 401-500(the pink one which also cant be seen at all), same goes for motorbikes, why choose the smaller cc of the higher range when u can just get the bigger cc of the range.
#
# And this are the cc rating that the population here is using,
#
# 1. 200cc and below is categorized as the lower range bike which is called class 2b.
#
# 2. 201-399cc is categorized as the mid range bike which is called class 2a,
#
# 3. Anything that is 400cc and above, is called the higher range bike called class 2.
#
# So I'll be focusing more on the top 5 brands used and the 3 classes based on the top 4 cc ratings.

# %% [markdown]
# # DF

# %% [markdown]
# From df, can narrow down to the amount of brands for ML so easier to Look at and train test split

# %%
df.head(2)
# Out:
#    Unnamed: 0                 motor_name motor_price  Brand  \
# 0           0  Honda VFR800X CrossRunner       16800  honda
# 1           1  Honda VFR800X CrossRunner       16800  honda
#
#                        model  engine_cap_x classification type_of_vehicle  \
# 0  Honda VFR800X CrossRunner           782        Class 2   Sport Tourers
# 1  Honda VFR800X CrossRunner           782        Class 2   Sport Tourers
#
#                  Model  Year  ... Power (hp)  Engine cylinder  Engine stroke  \
# 0  vfr800x crossrunner  2015  ...      107.0               V4    four-stroke
# 1  vfr800x crossrunner  2017  ...      107.0               V4    four-stroke
#
#    Gearbox Fuel capacity (lts) Transmission type  \
# 0  6-speed                20.8             Chain
# 1  6-speed                20.8             Chain
#
#                                         Front brakes  \
# 0  Double disc. ABS. Floating discs. Hydraulic. F...
# 1  Double disc. ABS. Floating discs. Hydraulic. F...
#
# ...

# %%
print("Shape",df.shape)  # Display the shape number of rows and number of columns
print(df.dtypes)
# Out:
# Shape (4127, 22)
# Unnamed: 0               int64
# motor_name              object
# motor_price             object
# Brand                   object
# model                   object
# engine_cap_x             int64
# classification          object
# type_of_vehicle         object
# Model                   object
# Year                     int64
# Category                object
# engine_cap_y           float64
# Power (hp)             float64
# Engine cylinder         object
# Engine stroke           object
# Gearbox                 object
# Fuel capacity (lts)    float64
# Transmission type       object
# Front brakes            object
# Rear brakes             object
# Front suspension        object
# Rear suspension         object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'motor_name', 'motor_price', 'Brand', 'model',
#        'engine_cap_x', 'classification', 'type_of_vehicle', 'Model', 'Year',
#        'Category', 'engine_cap_y', 'Power (hp)', 'Engine cylinder',
#        'Engine stroke', 'Gearbox', 'Fuel capacity (lts)', 'Transmission type',
#        'Front brakes', 'Rear brakes', 'Front suspension', 'Rear suspension'],
#       dtype='object')

# %%
#df.drop(columns=['Year'],inplace=True)

# %%
#duplication = df.duplicated().sum()
#rint('Total duplication:',duplication,'rows')
#f.drop_duplicates(inplace=True)

# %%
df.drop(columns=['Unnamed: 0','model','engine_cap_y'],inplace=True)

# %%
df.rename(columns={"engine_cap_x":"Engine capacity","motor_name":"Motor name","motor_price":"Motor Price","classification":"Classification","type_of_vehicle":"Vehicle Type"},inplace=True)

# %%
len(df)
# Out:
# 4127

# %%
df.head(2)
# Out:
#                   Motor name Motor Price  Brand  Engine capacity  \
# 0  Honda VFR800X CrossRunner       16800  honda              782
# 1  Honda VFR800X CrossRunner       16800  honda              782
#
#   Classification   Vehicle Type                Model  Year       Category  \
# 0        Class 2  Sport Tourers  vfr800x crossrunner  2015  Sport touring
# 1        Class 2  Sport Tourers  vfr800x crossrunner  2017  Sport touring
#
#    Power (hp) Engine cylinder Engine stroke  Gearbox  Fuel capacity (lts)  \
# 0       107.0              V4   four-stroke  6-speed                 20.8
# 1       107.0              V4   four-stroke  6-speed                 20.8
#
#   Transmission type                                       Front brakes  \
# 0             Chain  Double disc. ABS. Floating discs. Hydraulic. F...
# 1             Chain  Double disc. ABS. Floating discs. Hydraulic. F...
#
#                                          Rear brakes  \
# ...

# %%
df.dtypes
# Out:
# Motor name              object
# Motor Price             object
# Brand                   object
# Engine capacity          int64
# Classification          object
# Vehicle Type            object
# Model                   object
# Year                     int64
# Category                object
# Power (hp)             float64
# Engine cylinder         object
# Engine stroke           object
# Gearbox                 object
# Fuel capacity (lts)    float64
# Transmission type       object
# Front brakes            object
# Rear brakes             object
# Front suspension        object
# Rear suspension         object
# dtype: object

# %%
df.isna().sum()
# Out:
# Motor name                0
# Motor Price               0
# Brand                     0
# Engine capacity           0
# Classification            0
# Vehicle Type              0
# Model                     0
# Year                      0
# Category                  0
# Power (hp)             1094
# Engine cylinder           0
# Engine stroke             0
# Gearbox                 209
# Fuel capacity (lts)     149
# Transmission type       148
# Front brakes             14
# Rear brakes              15
# Front suspension        118
# Rear suspension         109
# dtype: int64

# %%
df.loc[df.index[df['Motor name']=='Honda PCX150'],'Power (hp)']
# Out:
# 59    NaN
# 60    NaN
# 61    NaN
# 62    NaN
# 63    NaN
# 64    NaN
# 65    NaN
# 66    NaN
# 67    NaN
# 68    NaN
# 69    NaN
# 70    NaN
# 71    NaN
# 72    NaN
# 73    NaN
# 74    NaN
# 75    NaN
# 76    NaN
# 77    NaN
# 78    NaN
# 79    NaN
# 80    NaN
# 81    NaN
# 82    NaN
# 83    NaN
# 84    NaN
# 85    NaN
# 86    NaN
# 87    NaN
# 88    NaN
# 89    NaN
# 90    NaN
# 91    NaN
# 92    NaN
# 93    NaN
# 94    NaN
# 95    NaN
# 96    NaN
# 97    NaN
# 98    NaN
# 99    NaN
# 100   NaN
# 101   NaN
# 102   NaN
# 103   NaN
# 104   NaN
# 105   NaN
# 106   NaN
# 107   NaN
# 108   NaN
# 109   NaN
# 110   NaN
# 111   NaN
# 112   NaN
# 113   NaN
# 114   NaN
# Name: Power (hp), dtype: float64

# %%
df.loc[df.index[df['Motor name']=='Honda PCX150'],'Power (hp)'] = 13.5
df.loc[df.index[df['Motor name']=='Kawasaki Z1000 ABS'],'Power (hp)'] = 140.14
df.loc[df.index[df['Motor name']=='Suzuki GSX-R1000'],'Power (hp)'] = 202.0
df.loc[df.index[df['Motor name']=='SYM Joyride 200i Evo'],'Power (hp)'] = 15.0
df.loc[df.index[df['Motor name']=='SYM Joyride 200i Evo'],'Power (hp)'] = 15.0
df.loc[df.index[df['Motor name']=='Yamaha YZF-R15'],'Power (hp)'] = 19.0
df.loc[df.index[df['Motor name']=='SYM GTS 200'],'Power (hp)'] = 14.3
df.loc[df.index[df['Motor name']=='Suzuki GSX-S1000'],'Power (hp)'] = 150.0
df.loc[df.index[df['Motor name']=='Suzuki V-Strom 1000 ABS Adventure'],'Power (hp)'] = 99.0
df.loc[df.index[df['Motor name']=='Yamaha MT-03'],'Power (hp)'] = 50.0
df.loc[df.index[df['Motor name']=='Suzuki Burgman 200'],'Power (hp)'] = 18.1
df.loc[df.index[df['Motor name']=='Honda CB1000R'],'Power (hp)'] = 109.4
df.loc[df.index[df['Motor name']=='Yamaha YZF-R3'],'Power (hp)'] = 36.0
df.loc[df.index[df['Motor name']=='Kawasaki Versys-X 300'],'Power (hp)'] = 40.0
df.loc[df.index[df['Motor name']=='Yamaha TW200'],'Power (hp)'] = 16.0
df.loc[df.index[df['Motor name']=='Honda CBR150R'],'Power (hp)'] = 18.0
df.loc[df.index[df['Motor name']=='Yamaha FZ16'],'Power (hp)'] = 14.0
df.loc[df.index[df['Motor name']=='Yamaha YZF-R6'],'Power (hp)'] = 108.0
df.loc[df.index[df['Motor name']=='Kawasaki Z750'],'Power (hp)'] = 104.2
df.loc[df.index[df['Motor name']=='KTM 350 EXC-F'],'Power (hp)'] = 5.4
df.loc[df.index[df['Motor name']=='KTM 200 Duke'],'Power (hp)'] = 26.0
df.loc[df.index[df['Motor name']=='Honda CBR1000RR'],'Power (hp)'] = 217.0
df.loc[df.index[df['Motor name']=='Yamaha YZF-R1'],'Power (hp)'] = 198.0
df.loc[df.index[df['Motor name']=='Honda CBR500R'],'Power (hp)'] = 43.2
df.loc[df.index[df['Motor name']=='Yamaha MT-10'],'Power (hp)'] = 158.2
df.loc[df.index[df['Motor name']=='Indian Springfield Dark Horse'],'Power (hp)'] = 90.0
df.loc[df.index[df['Motor name']=='Honda CBR600RR'],'Power (hp)'] = 113.0
df.loc[df.index[df['Motor name']=='Yamaha XT1200Z Super Tenere'],'Power (hp)'] = 113.2
df.loc[df.index[df['Motor name']=='Suzuki GSR750'],'Power (hp)'] = 106.0
df.loc[df.index[df['Motor name']=='KTM 1290 Super Duke R'],'Power (hp)'] = 180.0
df.loc[df.index[df['Motor name']=='Honda PCX160'],'Power (hp)'] = 15.8
df.loc[df.index[df['Motor name']=='Suzuki V-Strom 1000'],'Power (hp)'] = 99.0
df.loc[df.index[df['Motor name']=='Kawasaki Versys 650'],'Power (hp)'] = 65.7
df.loc[df.index[df['Motor name']=='Honda NM4 Vultus'],'Power (hp)'] = 54.0
df.loc[df.index[df['Motor name']=='Suzuki V-Strom 650'],'Power (hp)'] = 70.0
df.loc[df.index[df['Motor name']=='Rieju Marathon Pro 200'],'Power (hp)'] = 19.0
df.loc[df.index[df['Motor name']=='Honda CB300R'],'Power (hp)'] = 25.0
df.loc[df.index[df['Motor name']=='Honda CB300F'],'Power (hp)'] = 24.5
df.loc[df.index[df['Motor name']=='Honda CB1100'],'Power (hp)'] = 90.0
df.loc[df.index[df['Motor name']=='Daelim B-bone 125'],'Power (hp)'] = 11.5
df.loc[df.index[df['Motor name']=='Bimota Tesi 3D'],'Power (hp)'] = 100.0
df.loc[df.index[df['Motor name']=='Adiva AD3 300'],'Power (hp)'] = 29.4
df.loc[df.index[df['Motor name']=='Indian Springfield'],'Power (hp)'] = 90.0
df.loc[df.index[df['Motor name']=='Kawasaki Ninja 400'],'Power (hp)'] = 49.0
df.loc[df.index[df['Motor name']=='KTM 525 EXC Racing'],'Power (hp)'] = 61.0
df.loc[df.index[df['Motor name']=='Honda CBR250R'],'Power (hp)'] = 26.7
df.loc[df.index[df['Motor name']=='Honda NC700X'],'Power (hp)'] = 51.1
df.loc[df.index[df['Motor name']=='Honda XR650L'],'Power (hp)'] = 40.0
df.loc[df.index[df['Motor name']=='Honda Super Cub C125'],'Power (hp)'] = 9.1
df.loc[df.index[df['Motor name']=='Honda Shadow Phantom'],'Power (hp)'] = 44.9
df.loc[df.index[df['Motor name']=='Honda Rebel 300'],'Power (hp)'] = 25.0
df.loc[df.index[df['Motor name']=='Honda CTX700N'],'Power (hp)'] = 51.1
df.loc[df.index[df['Motor name']=='Honda CTX700 DCT'],'Power (hp)'] = 48.0 
df.loc[df.index[df['Motor name']=='Honda CRF450X'],'Power (hp)'] = 40
df.loc[df.index[df['Motor name']=='Honda CRF450R'],'Power (hp)'] = 55.2
df.loc[df.index[df['Motor name']=='Honda CRF250X'],'Power (hp)'] = 29.4
df.loc[df.index[df['Motor name']=='Honda CRF250R'],'Power (hp)'] ==37.6
df.loc[df.index[df['Motor name']=='Kawasaki Concours 14 ABS'],'Power (hp)'] = 158.0
df.loc[df.index[df['Motor name']=='Indian Scout Bobber'],'Power (hp)'] = 100.0
df.loc[df.index[df['Motor name']=='Indian Scout'],'Power (hp)'] = 100.0
df.loc[df.index[df['Motor name']=='Indian Roadmaster'],'Power (hp)'] = 73.0
df.loc[df.index[df['Motor name']=='Indian Chieftain Limited'],'Power (hp)'] = 84.8
df.loc[df.index[df['Motor name']=='Indian Chieftain Dark Horse'],'Power (hp)'] = 84.8
df.loc[df.index[df['Motor name']=='Indian Chieftain Classic'],'Power (hp)'] = 90.0
df.loc[df.index[df['Motor name']=='Indian Chieftain'],'Power (hp)'] = 84.8
df.loc[df.index[df['Motor name']=='Indian Chief Vintage'],'Power (hp)'] = 85
df.loc[df.index[df['Motor name']=='Indian Chief Dark Horse'],'Power (hp)'] = 75.0
df.loc[df.index[df['Motor name']=='Hyosung GD250R'],'Power (hp)'] = 28.4
df.loc[df.index[df['Motor name']=='Husqvarna TE125'],'Power (hp)'] = 15.0

# %%
df.isna().sum()
# Out:
# Motor name               0
# Motor Price              0
# Brand                    0
# Engine capacity          0
# Classification           0
# Vehicle Type             0
# Model                    0
# Year                     0
# Category                 0
# Power (hp)             453
# Engine cylinder          0
# Engine stroke            0
# Gearbox                209
# Fuel capacity (lts)    149
# Transmission type      148
# Front brakes            14
# Rear brakes             15
# Front suspension       118
# Rear suspension        109
# dtype: int64

# %%
df['Power (hp)'] = df['Power (hp)'].fillna('0').astype(str)

# %%
df.Brand.value_counts()
# Out:
# yamaha        978
# honda         730
# suzuki        428
# triumph       365
# ktm           295
# kawasaki      289
# ducati        254
# mv agusta     130
# indian         93
# aprilia        78
# bmw            78
# vespa          45
# bajaj          43
# moto guzzi     42
# hyosung        29
# bimota         28
# sym            27
# keeway         25
# husqvarna      21
# norton         21
# rieju          17
# lambretta      16
# kymco          16
# lexmoto        16
# piaggio        15
# tvs            11
# megelli         8
# adiva           7
# can-am          6
# brixton         3
# benelli         3
# pgo             3
# daelim          3
# modenas         2
# peugeot         1
# tgb             1
# Name: Brand, dtype: int64

# %% [markdown]
# Dropping brands that are not part of the top 5 brands

# %% [markdown]
# - 101-200cc, 200 and below is class 2b
# - 301-400cc, class 2a
# - 501-1000cc, class2
# - 1001cc and above, class2

# %%
brand_name = ['honda','yamaha','piaggio','suzuki','sym']
cc_rate = ['101','200','301','400','501']

# %%
class_2b = df.loc[(df['Brand'].isin(brand_name)) & (df['Engine capacity'] >= int(cc_rate[0])) & (df['Engine capacity'] <= int(cc_rate[1]))]
class_2a = df.loc[(df['Brand'].isin(brand_name)) & (df['Engine capacity'] >= int(cc_rate[2])) & (df['Engine capacity'] <= int(cc_rate[3]))]
class_2 = df.loc[(df['Brand'].isin(brand_name)) & (df['Engine capacity'] >= int(cc_rate[4]))]

# %%
class_2b.head(2)
# Out:
#       Motor name Motor Price  Brand  Engine capacity Classification  \
# 59  Honda PCX150        9222  honda              153       Class 2B
# 60  Honda PCX150        9222  honda              153       Class 2B
#
#    Vehicle Type   Model  Year Category Power (hp)  Engine cylinder  \
# 59     Scooters  pcx150  2013  Scooter       13.5  Single cylinder
# 60     Scooters  pcx150  2014  Scooter       13.5  Single cylinder
#
#    Engine stroke    Gearbox  Fuel capacity (lts) Transmission type  \
# 59   four-stroke  Automatic                 6.06              Belt
# 60   four-stroke  Automatic                 6.06              Belt
#
#    Front brakes                   Rear brakes     Front suspension  \
# 59  Single disc  Expanding brake (drum brake)  31mm hydraulic fork
# 60  Single disc  Expanding brake (drum brake)  31mm hydraulic fork
#
#                         Rear suspension
# 59  Unit swingarm, 3.1 inches of travel
# 60  Unit swingarm, 3.1 inches of travel

# %%
class_2a.head(2)
# Out:
#            Motor name Motor Price  Brand  Engine capacity Classification  \
# 115  Honda Shadow 400       12800  honda              398       Class 2A
# 116  Honda Shadow 400       12800  honda              398       Class 2A
#
#     Vehicle Type       Model  Year          Category Power (hp)  \
# 115      Cruiser  shadow 400  2002  Custom / cruiser       33.0
# 116      Cruiser  shadow 400  2016  Custom / cruiser       30.8
#
#     Engine cylinder Engine stroke  Gearbox  Fuel capacity (lts)  \
# 115              V2   four-stroke  5-speed                 14.0
# 116              V2   four-stroke  5-speed                 14.0
#
#     Transmission type                                 Front brakes  \
# 115               NaN                                  Single disc
# 116       Shaft drive  Single disc. Two-piston calipers, hydraulic
#
#                       Rear brakes  Front suspension  \
# 115               Expanding brake               NaN
# ...

# %%
class_2.head(2)
# Out:
#                   Motor name Motor Price  Brand  Engine capacity  \
# 0  Honda VFR800X CrossRunner       16800  honda              782
# 1  Honda VFR800X CrossRunner       16800  honda              782
#
#   Classification   Vehicle Type                Model  Year       Category  \
# 0        Class 2  Sport Tourers  vfr800x crossrunner  2015  Sport touring
# 1        Class 2  Sport Tourers  vfr800x crossrunner  2017  Sport touring
#
#   Power (hp) Engine cylinder Engine stroke  Gearbox  Fuel capacity (lts)  \
# 0      107.0              V4   four-stroke  6-speed                 20.8
# 1      107.0              V4   four-stroke  6-speed                 20.8
#
#   Transmission type                                       Front brakes  \
# 0             Chain  Double disc. ABS. Floating discs. Hydraulic. F...
# 1             Chain  Double disc. ABS. Floating discs. Hydraulic. F...
#
#                                          Rear brakes  \
# ...

# %%
df1 = pd.concat([class_2b,class_2a,class_2], axis=0).reset_index()
df1['Total'] = 1
print(len(df1))
df1.head()
# Out:
# 1867
#    index    Motor name Motor Price  Brand  Engine capacity Classification  \
# 0     59  Honda PCX150        9222  honda              153       Class 2B
# 1     60  Honda PCX150        9222  honda              153       Class 2B
# 2     61  Honda PCX150        9222  honda              153       Class 2B
# 3     62  Honda PCX150        9222  honda              153       Class 2B
# 4     63  Honda PCX150        9222  honda              153       Class 2B
#
#   Vehicle Type   Model  Year Category  ...  Engine cylinder Engine stroke  \
# 0     Scooters  pcx150  2013  Scooter  ...  Single cylinder   four-stroke
# 1     Scooters  pcx150  2014  Scooter  ...  Single cylinder   four-stroke
# 2     Scooters  pcx150  2015  Scooter  ...  Single cylinder   four-stroke
# 3     Scooters  pcx150  2016  Scooter  ...  Single cylinder   four-stroke
# 4     Scooters  pcx150  2017  Scooter  ...  Single cylinder   four-stroke
#
# ...

# %%
price = list(df1['Motor Price'])
name = list(df1['Motor name'])

for value in range(len(price)):
    if '-' in price[value]:
        price[value] = price[value].replace('-','0')
    elif '1166612666' in price[value]:
        price[value] = price[value].replace('1166612666','12666')
    if 'Honda CRF450' in name[value]:
        price[value] = 13860
    if 'Honda CB650' in name[value]:
        price[value] = 25000
    if name [value] == 'Piaggio Liberty 125':
        price[value] = 3900
    if name [value] == 'Suzuki DR650SE':
        price[value] = 9900
    if 'Suzuki SV650' in name[value]:
        price[value] = 11820
    if name[value] == 'SYM Jet 4 125':
        price[value] = 5500
    if name[value] == 'Yamaha Zuma 125':
        price[value] = 3700
    if name[value] == 'Yamaha XT1200Z Super Tenere':
        price[value] = 16800

# %%
df1['Motor Price'] = price

# %%
df1.iloc[104:105,5] = 'Class 2B'

# %%
c_2b = len(class_2b)
c_2a = len(class_2a)
c_2 = len(class_2)
total = len(class_2b) + len(class_2a) + len(class_2)
print(f"{c_2b} + {c_2a} + {c_2} = {total}")
# Out:
# 561 + 206 + 1100 = 1867

# %%
df1.dtypes
# Out:
# index                    int64
# Motor name              object
# Motor Price             object
# Brand                   object
# Engine capacity          int64
# Classification          object
# Vehicle Type            object
# Model                   object
# Year                     int64
# Category                object
# Power (hp)              object
# Engine cylinder         object
# Engine stroke           object
# Gearbox                 object
# Fuel capacity (lts)    float64
# Transmission type       object
# Front brakes            object
# Rear brakes             object
# Front suspension        object
# Rear suspension         object
# Total                    int64
# dtype: object

# %%
df1.head(1)
# Out:
#    index    Motor name Motor Price  Brand  Engine capacity Classification  \
# 0     59  Honda PCX150        9222  honda              153       Class 2B
#
#   Vehicle Type   Model  Year Category  ...  Engine cylinder Engine stroke  \
# 0     Scooters  pcx150  2013  Scooter  ...  Single cylinder   four-stroke
#
#      Gearbox Fuel capacity (lts)  Transmission type Front brakes  \
# 0  Automatic                6.06               Belt  Single disc
#
#                     Rear brakes     Front suspension  \
# 0  Expanding brake (drum brake)  31mm hydraulic fork
#
#                        Rear suspension Total
# 0  Unit swingarm, 3.1 inches of travel     1
#
# [1 rows x 21 columns]

# %%
df1['Motor Price'] = df1['Motor Price'].astype(float)
df1['Engine capacity'] = df1['Engine capacity'].astype(float)
df1['Power (hp)'] = df1['Power (hp)'].astype(float)

# %%
df1.to_csv('df1.csv')

# %%
df1.groupby(['Brand'])[['Total']].sum()
# Out:
#          Total
# Brand
# honda      535
# piaggio     12
# suzuki     410
# sym         24
# yamaha     886

# %%
df1.groupby(['Brand'])[['Total']].sum().plot.barh(figsize=(4,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Brand'>

# %% [markdown]
# The motorcycle type available for each Brand

# %%
df1.groupby(['Brand','Model'])[['Total']].count()
# Out:
#                   Total
# Brand  Model
# honda  cb1000r       42
#        cb1100         5
#        cb1100 ex      5
#        cb125f        12
#        cb125r         8
# ...                 ...
# yamaha yzf-r1m        8
#        yzf-r3        56
#        yzf-r6        46
#        yzf-r7         6
#        zuma 125      13
#
# [147 rows x 1 columns]

# %%
df1.loc[(df1['Brand']==brand_name[0])].groupby(['Classification','Model'])[['Total']].count().plot.barh(figsize=(5,10),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Classification,Model'>

# %%
df1.loc[(df1['Brand']==brand_name[1])].groupby(['Brand','Model'])[['Total']].count().plot.barh(figsize=(5,12),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Brand,Model'>

# %%
df1.loc[(df1['Brand']==brand_name[2])].groupby(['Brand','Model'])[['Total']].count().plot.barh(figsize=(3,1),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Brand,Model'>

# %%
df1.loc[(df1['Brand']==brand_name[3])].groupby(['Brand','Model'])[['Total']].count().plot.barh(figsize=(5,10),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Brand,Model'>

# %%
df1.loc[(df1['Brand']==brand_name[4])].groupby(['Brand','Model'])[['Total']].count().plot.barh(figsize=(3,2),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Brand,Model'>

# %% [markdown]
# Showing the amount of types in one particular model with different prices, year and specifications

# %% [markdown]
# Can see that in the market, there's alot of class 2 still in stock compared to class 2b and 2a

# %%
brand_price = df1.groupby(['Classification','Brand'])[['Motor Price']].mean()
brand_price.sort_values(by=['Motor Price','Classification']).plot.barh(figsize=(5,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Classification,Brand'>

# %% [markdown]
# The higher range of cc rating bikes are more expensive than the mid and lower range bikes

# %%
class_type = df1.groupby(['Classification','Vehicle Type'])[['Motor Price']].mean()
class_type.sort_values(by=['Classification','Motor Price']).plot.barh(figsize=(6,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Classification,Vehicle Type'>

# %% [markdown]
# Scooters price range about the same as Dirt bike/sports bike in their classes individually, with this price range, will give customers a better range to choose on getting their preferred choice of purchase.

# %%
class_gear = df1.groupby(['Classification','Gearbox'])[['Total']].sum()
class_gear.sort_values(by=['Classification','Total']).plot.barh(figsize=(4,3),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Classification,Gearbox'>

# %%
df1.groupby(['Engine capacity','Motor name'],sort=False)[['Motor Price']].mean()
# Out:
#                                                Motor Price
# Engine capacity Motor name
# 153.0           Honda PCX150                   6842.000000
# 149.0           Honda PCX150                   7800.000000
# 155.0           Yamaha Nmax 155               13497.857143
# 171.0           SYM Joyride 200i Evo           5350.000000
# 155.0           Yamaha YZF-R15                13594.444444
# ...                                                    ...
# 562.0           Yamaha Tmax 560                4000.000000
# 1304.0          Yamaha V-Star 1300 Deluxe SE      0.000000
# 1679.0          Yamaha Vmax                   10000.000000
# 998.0           Yamaha YZF-R1M                 6000.000000
# 689.0           Yamaha YZF-R7                  6000.000000
#
# [163 rows x 1 columns]

# %%
clas_cc = df1.groupby(['Engine capacity','Motor name'],sort=False)[['Motor Price']].mean().head(15)
clas_cc.sort_values(by=['Motor Price']).plot.barh(figsize=(8,15),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Engine capacity,Motor name'>

# %%
df1.groupby(['Transmission type','Motor name'])[['Fuel capacity (lts)']].max()
# Out:
#                                                      Fuel capacity (lts)
# Transmission type Motor name
# Belt              Honda Forza 125                                  11.50
#                   Honda Forza 350                                  11.70
#                   Honda Forza 750                                  13.20
#                   Honda PCX125                                      8.00
#                   Honda PCX150                                      7.95
# ...                                                                  ...
# Shaft drive       Suzuki Boulevard M90                             18.20
#                   Suzuki Burgman 650                               15.00
#                   Yamaha FJR1300AE Ultimate Edition                25.00
#                   Yamaha Vmax                                      15.14
#                   Yamaha XT1200Z Super Tenere                      23.09
#
# [150 rows x 1 columns]

# %%
clas_cc = df1.loc[df1['Transmission type']=='Belt'].groupby(['Transmission type','Motor name'])[['Fuel capacity (lts)']].max().head(10)
clas_cc.sort_values(by=['Fuel capacity (lts)']).plot.barh(figsize=(4,6),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Transmission type,Motor name'>

# %%
clas_cc = df1.loc[df1['Transmission type']=='Shaft drive'].groupby(['Transmission type','Motor name'])[['Fuel capacity (lts)']].max().head(10)
clas_cc.sort_values(by=['Fuel capacity (lts)']).plot.barh(figsize=(4,6),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Transmission type,Motor name'>

# %%
clas_cc = df1.loc[df1['Transmission type']=='Chain'].groupby(['Transmission type','Motor name'])[['Fuel capacity (lts)']].max().head(10)
clas_cc.sort_values(by=['Fuel capacity (lts)']).plot.barh(figsize=(4,6),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Transmission type,Motor name'>

# %%
df1['Transmission type'].unique()
# Out:
# array(['Belt', nan, 'Chain', 'Shaft drive'], dtype=object)

# %%
df1['Category'].unique()
# Out:
# array(['Scooter', 'Sport', 'Naked bike', 'Allround', 'Enduro / offroad',
#        'Super motard', 'Classic', 'Cross / motocross', 'Custom / cruiser',
#        'Sport touring', 'Touring'], dtype=object)

# %%
clas_cc = df1.loc[df1['Category']=='Scooter'].groupby(['Motor name','Gearbox'])[['Engine capacity']].max()
clas_cc.sort_values(by=['Engine capacity']).plot.barh(figsize=(8,15),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Motor name,Gearbox'>

# %%
clas_cc = df1.loc[df1['Category']=='Naked bike'].groupby(['Motor name','Gearbox'])[['Engine capacity']].max()
clas_cc.sort_values(by=['Engine capacity']).plot.barh(figsize=(8,15),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Motor name,Gearbox'>

# %%
df1.columns
# Out:
# Index(['index', 'Motor name', 'Motor Price', 'Brand', 'Engine capacity',
#        'Classification', 'Vehicle Type', 'Model', 'Year', 'Category',
#        'Power (hp)', 'Engine cylinder', 'Engine stroke', 'Gearbox',
#        'Fuel capacity (lts)', 'Transmission type', 'Front brakes',
#        'Rear brakes', 'Front suspension', 'Rear suspension', 'Total'],
#       dtype='object')

# %%
clas_cc = df1.loc[df1['Power (hp)']>=100].groupby(['Motor name','Gearbox'])[['Power (hp)']].max()
clas_cc.sort_values(by=['Power (hp)']).plot.barh(figsize=(10,19),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Motor name,Gearbox'>

# %%
clas_cc = df1.loc[df1['Power (hp)']>0].groupby(['Motor name','Gearbox'])[['Power (hp)']].max()
clas_cc.sort_values(by=['Power (hp)']).plot.barh(figsize=(10,30),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Motor name,Gearbox'>

# %%
clas_cc = df1.loc[df1['Power (hp)']>180].groupby(['Motor name','Gearbox'])[['Power (hp)']].max().head(3)
clas_cc.sort_values(by=['Power (hp)']).plot.barh(figsize=(6,2),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Motor name,Gearbox'>

# %%
# Out:
#                                 Power (hp)
# Motor name           Gearbox
# Honda PCX150         Automatic        13.5
# Yamaha Nmax 155      Automatic        14.9
# SYM Joyride 200i Evo Automatic        15.0

# %%
clas_cc = df1.loc[df1['Power (hp)']<= 80.0].groupby(['Motor name','Gearbox'],sort=True)[['Power (hp)']].max().head(3)
clas_cc.sort_values(by=['Power (hp)']).plot.barh(figsize=(6,2),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Motor name,Gearbox'>

# %%
clas_cc = df1.loc[df1['Power (hp)']<= 23.0].groupby(['Motor name','Gearbox'])[['Power (hp)']].max()#.head(3)
clas_cc.sort_values(by=['Power (hp)']).plot.barh(figsize=(6,20),color= 'midnightblue',  edgecolor='firebrick')
# Out:
# <AxesSubplot: ylabel='Motor name,Gearbox'>
